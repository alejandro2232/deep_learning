# %% [markdown]
# # Sección nueva

# %% [markdown]
# #Descripcion
#
# ---
#
#
#
# *   @Author:
# *   @Date:
# *   @Description: this notebook python basic exercise in python

# %% [markdown]
# #Ejercicios basicos

# %% [markdown]
# #Ejercicio 01 producto + iva

# %%
prod1,prod2,prod3,prod4,prod5= input("input product ").split(",");
suma = int(prod1) + int(prod2) + int(prod3) + int(prod4) + int(prod5);
print()
iva= int(suma) * 0.19;
print()
valorTotal = int(suma) + iva;
print("Suma: ",suma,"   Iva: ",iva, "   Valor total: ", valorTotal);
# Out:
# input product 10,20,30,40,50
#
#
# Suma:  150    Iva:  28.5    Valor total:  178.5

# %% [markdown]
# #Ejercicio 02

# %%
num1= int(input("Input number one"));
num2= int(input("Input number two"));
num3 = int(input("Input number three"));
if num1 > num2 & num1 > num3 :
  print("El numero ", num1, " es el mayor")
elif num2 > num1 & num2 > num3:
  print("El numero ", num2, " es el mayor")
else:
  print("El numero ", num3, "es el mayor")
# Out:
# Input number one1
# Input number two2
# Input number three3
# El numero  3 es el mayor

# %%
num1,num2,num3 = input("input the 3 numbers ").split(",");
lista = [int(num1),int(num2),int(num3)];
print("El numero mayor es: ",max(num1,num2,num3), ", el numero menor es: ",min(num1,num2,num3), " y el promedio es ", sum(lista)/len(lista));
print();
# Out:
# input the 3 numbers 10,20,30
# El numero mayor es:  30 , el numero menor es:  10  y el promedio es  20.0

# %% [markdown]
# #Ejercicio 03

# %%
import random

lista = [random.randint(1, 10) for x in range(int(input("input the amount of numbers in the list ")))]
lista.sort();
print("Smallest to largest = ",lista);
lista.sort(reverse=True)
print("Largest to smallest = ",lista);




# lista = random.sample(range(10), cantidad);
# Out:
# input the amount of numbers in the list 10
# Smallest to largest =  [1, 1, 3, 3, 4, 5, 5, 5, 10, 10]
# Largest to smallest =  [10, 10, 5, 5, 5, 4, 3, 3, 1, 1]
